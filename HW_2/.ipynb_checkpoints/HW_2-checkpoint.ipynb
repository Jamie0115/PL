# %%
#將資料化為易讀形式並印出
import json
Open = open('film.json')
Data = json.load(Open)
import pprint as pp
pp.pprint(Data, sort_dicts=False)
# Out:
# {'start': '2020-06-01T00:00:00',
#  'end': '2020-06-07T00:00:00',
#  'list': [{'country': '日本',
#            'name': '電影版 吹響吧！上低音號~莉茲與青鳥~',
#            'releaseDate': '2018-10-05T00:00:00',
#            'issue': '車庫娛樂股份有限公司',
#            'produce': '(美國)PONYCANYON USA INC.',
#            'theaterCount': 14,
#            'tickets': 417,
#            'ticketChangeRate': 0.08031088082901554,
#            'amounts': 104194.0,
#            'totalTickets': 11766,
#            'totalAmounts': 2920016.0},
#           {'country': '日本',
#            'name': '夏目友人帳劇場版 緣結空蟬',
#            'releaseDate': '2018-12-07T00:00:00',
#            'issue': '木棉花國際股份有限公司',
#            'produce': 'ANIPLEX INC.',
#            'theaterCount': 4,
#            'tickets': 3,
#            'ticketChangeRate': -0.9,
#            'amounts': 650.0,
#            'totalTickets': 23334,
#            'totalAmounts': 5437422.0},
#           {'country': '大陸',
#            'name': '大象席地而坐',
# ...

# %%
#匯入json檔案，存入dict中
film = open('film.json',encoding="utf8")
Data = json.load(film)
type(Data)
# Out:
# dict

# %%
#列出所有資料
Data.items()
# Out:
# dict_items([('start', '2020-06-01T00:00:00'), ('end', '2020-06-07T00:00:00'), ('list', [{'country': '日本', 'name': '電影版 吹響吧！上低音號~莉茲與青鳥~', 'releaseDate': '2018-10-05T00:00:00', 'issue': '車庫娛樂股份有限公司', 'produce': '(美國)PONYCANYON USA INC.', 'theaterCount': 14, 'tickets': 417, 'ticketChangeRate': 0.08031088082901554, 'amounts': 104194.0, 'totalTickets': 11766, 'totalAmounts': 2920016.0}, {'country': '日本', 'name': '夏目友人帳劇場版 緣結空蟬', 'releaseDate': '2018-12-07T00:00:00', 'issue': '木棉花國際股份有限公司', 'produce': 'ANIPLEX INC.', 'theaterCount': 4, 'tickets': 3, 'ticketChangeRate': -0.9, 'amounts': 650.0, 'totalTickets': 23334, 'totalAmounts': 5437422.0}, {'country': '大陸', 'name': '大象席地而坐', 'releaseDate': '2019-01-11T00:00:00', 'issue': '繁盛映畫有限公司', 'produce': '赤角（北京）文化傳播有限公司', 'theaterCount': 4, 'tickets': 80, 'ticketChangeRate': -0.7777777777777778, 'amounts': 22995.0, 'totalTickets': 28825, 'totalAmounts': 7301881.0}, {'country': '加拿大', 'name': '哈柏太空之旅 3D', 'releaseDate': '2019-02-04T00:00:00', 'issu
# ...

# %%
temp = Data.get("list")

# %%
#查詢球員之得分
ask = input("請輸入想知道的電影名稱是哪個國家製作的")
for i in temp:
    if ask == i.get("name"):
        print(ask, "的分數為", i.get("countey"))
