# %%
import requests 
import json
import time
from time import sleep
import pandas as pd

# %%
### 裁判家網址：https://www.lawplus.com.tw/
### 關鍵字：全文搜索：車禍
page = 1
urlfirst = "https://www.lawplus.com.tw/rest/search/report?querySentence=%E8%BB%8A%E7%A6%8D"
link = urlfirst + str(page) + urlsec
link
# Out:
# 'https://www.lawplus.com.tw/rest/search/report?querySentence=(%E8%BB%8A%E7%A6%8D%2B%E4%BA%A4%E9%80%9A%E4%BA%8B%E6%95%85)%26(%E6%B0%91%E6%B3%95%E7%AC%AC217%2B%E9%81%8E%E5%A4%B1%E6%AF%94%E4%BE%8B)&keyword=(%E8%BB%8A%E7%A6%8D%2B%E4%BA%A4%E9%80%9A%E4%BA%8B%E6%95%85)%26(%E6%B0%91%E6%B3%95%E7%AC%AC217%2B%E9%81%8E%E5%A4%B1%E6%AF%94%E4%BE%8B)&prevKeyword=(%E8%BB%8A%E7%A6%8D%2B%E4%BA%A4%E9%80%9A%E4%BA%8B%E6%95%85)%26(%E6%B0%91%E6%B3%95%E7%AC%AC217%2B%E9%81%8E%E5%A4%B1%E6%AF%94%E4%BE%8B)&date=2012%2F05%2F16~2022%2F05%2F16&money=&sentence=&caseNum=&caseTypes=&courts=&levels=1&jtypes=&tags=&issue=&main=&judge=&judgeTypes=&lawyer=&litigant=&prosecutor=&clerk=&rows=10&page=1&sortField=&_=1652714083801'

# %%
### 裁判家網址：https://www.lawplus.com.tw/
### 關鍵字：全文搜索：車禍 交通事故 一審判決
### URL: https://www.lawplus.com.tw/#/searchReport?query=%25E8%25BB%258A%25E7%25A6%258D%2520%25E4%25BA%25A4%25E9%2580%259A%25E4%25BA%258B%25E6%2595%2585%25E4%25B8%2580%25E5%25AF%25A9%25E5%2588%25A4%25E6%25B1%25BA

# %%
urlfirst="https://www.lawplus.com.tw/rest/search/report?querySentence=(%25E8%25BB%258A%25E7%25A6%258D%2520%25E4%25BA%25A4%25E9%2580%259A%25E4%25BA%258B%25E6%2595%2585%25E4%25B8%2580%25E5%25AF%25A9%25E5%2588%25A4%25E6%25B1%25BA&page="
urlfirst
# Out:
# 'https://www.lawplus.com.tw/rest/search/report?querySentence=(%25E8%25BB%258A%25E7%25A6%258D%2520%25E4%25BA%25A4%25E9%2580%259A%25E4%25BA%258B%25E6%2595%2585%25E4%25B8%2580%25E5%25AF%25A9%25E5%2588%25A4%25E6%25B1%25BA&page='

# %%
#&page=1
page = "1"
link = urlfirst + page + ')'
link
# Out:
# 'https://www.lawplus.com.tw/rest/search/report?querySentence=(%25E8%25BB%258A%25E7%25A6%258D%2520%25E4%25BA%25A4%25E9%2580%259A%25E4%25BA%258B%25E6%2595%2585%25E4%25B8%2580%25E5%25AF%25A9%25E5%2588%25A4%25E6%25B1%25BA&page=1)'

# %%
res = requests.get(urlfirst, verify=False)
# Out:
# C:\Users\funny\anaconda3\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.lawplus.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
res
# Out:
# <Response [200]>

# %%
data = json.loads(res.text)
data
# Out:
# {'page': 1,
#  'records': 10891,
#  'rows': [{'caseNum': '105,投小,319',
#    'caseType': 'V',
#    'content': '臺灣南投地方法院民事小額判決\u3000\u3000\u3000\u3000105年度投小字第319號\r\n原\u3000\u3000\u3000告\u3000泰安產物保險股份有限公司\r\n法定代理人\u3000李松季\r\n訴訟代理人\u3000陳建興\r\n\u3000\u3000\u3000\u3000\u3000\u3000蔡松麟\r\n被\u3000\u3000\u3000告\u3000陳慶隆\r\n訴訟代...',
#    'court': '',
#    'identifier': 'NTEV,105,投小,319,20161124,1-80378243-52d7-4154-96bf-59579c9a47e0',
#    'issue': '損害賠償',
#    'jtype': 'J',
#    'judgeDate': '2016/11/24',
#    'litigant': None,
#    'tags': None,
#    'title': 'NTEV,105,投小,319,20161124,1-80378243-52d7-4154-96bf-59579c9a47e0',
#    'type': '民事判決'},
#   {'caseNum': '107,訴,1641',
#    'caseType': 'V',
#    'content': '臺灣桃園地方法院民事判決\u3000\u3000\u3000\u3000\u3000\u3000 107年度訴字第1641號\r\n原\u3000\u3000\u3000告\u3000新光產物保險股份有限公司桃園分公司\r\n法定代理人\u3000徐慶霖\r\n訴訟代理人\u3000葉書佑\r\n被\u3000\u3000\u3000告\u3000張凱雄\r\n上列當事人間請求...',
#    'court': '',
# ...

# %%
htmlRUL = 'https://www.ptt.cc/bbs/job/index.html'
htmlRUL
page = range(1,10)

for i in page:
    link = htmlRUL + str(i) + '.html'
    response = requests.get(link)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, "html.parser")
    soup.find_all(class_="title")
    for p in paragraphs:
        print(p.text)
# Out:
#
# 				modechao27: 缺標語
#
#
#
#
# 				elongation: 缺標語
#
#
#
# [台北] 國北教大自然系誠徵國科會計畫專任助理
#
#
# [台北] 勞資管理顧問公司 誠徵【業務助理】
#
#
# [徵]夏威夷花式鐵板燒內外場鐵板師傅學徒
#
#
# [北部] 中和徵內勤業務
#
#
# [北部] 國立清華大學中國文學系誠徵計畫行政助理
#
#
# [台北] 永和徵國小一年級班導師
#
#
# [中部] [大雅] 短期行政人員
#
#
# [台北] 台大國際產學聯盟誠徵國科會計畫助理專任
#
#
# [台北] 調鼎法律工場/律師助理
#
#
# [中部] 乂迪生科技 誠徵   晚班線上客服專員
#
#
# [台北] 包裝人員
#
#
# [北部] 門市正職/網路行銷人員(三峽北大)
#
#
# [台北] 台灣自殺防治學會 徵專任助理
#
#
# [台南] 台南市安平區誠徵會計助理
#
#
# [台北] 台大生機系先進材料實驗室徵專任研究助理
#
#
# [台北] 臺大醫院誠徵住院整合照護管理師
#
#
# [北部] 新北市就業服務處-徵業務輔導員
#
#
# [公告] 檢舉專區 噓徵人文 請寫上理由
#
#
# [公告] 2023年1/1增修板規  罰則修訂
#
#
# [公告] 不實資方 處理方式 ([黑名]前必看)
#
#
# [公告] 關於文章內容 或推/噓文內容 為"酸"言
#
#
# [公告] 徵人文章 要求貼照片 一律水桶七天
#
#
#
# 				modechao27: 缺標語
#
#
#
#
# 				elongation: 缺標語
#
#
#
# [台北] 國北教大自然系誠徵國科會計畫專任助理
#
#
# [台北] 勞資管理顧問公司 誠徵【業務助理】
#
#
# [徵]夏威夷花式鐵板燒內外場鐵板師傅學徒
#
#
# [北部] 中和徵內勤業務
#
#
# [北部] 國立清華大學中國文學系誠徵計畫行政助理
#
#
# [台北] 永和徵國小一年級班導師
#
#
# [中部] [大雅] 短期行政人員
#
#
# [台北] 台大國際產學聯盟誠徵國科會計畫助理專任
#
#
# [台北] 調鼎法律工場/律師助理
#
#
# [中部] 乂迪生科技 誠徵   晚班線上客服專員
#
#
# [台北] 包裝人員
#
#
# ...

# %%
htmlRUL = 'https://www.ptt.cc/bbs/job/index'
htmlRUL
pages = range(1,10)
allurl = list()
urlfirst = 'https://www.ptt.cc/'
for page in pages:
    link = htmlRUL + str(page) + '.html'
    response = requests.get(link)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, "html.parser")
    a_tags = soup.find_all('a')
    for a in a_tags:
        href = a.get('href')
        if href and href.startswith('/'):
            temp = urlfirst + href
            allurl.append(temp)

# %%
allurl
# Out:
# ['https://www.ptt.cc//bbs/',
#  'https://www.ptt.cc//bbs/job/index.html',
#  'https://www.ptt.cc//about.html',
#  'https://www.ptt.cc//contact.html',
#  'https://www.ptt.cc//bbs/job/index.html',
#  'https://www.ptt.cc//man/job/index.html',
#  'https://www.ptt.cc//bbs/job/index1.html',
#  'https://www.ptt.cc//bbs/job/index2.html',
#  'https://www.ptt.cc//bbs/job/index.html',
#  'https://www.ptt.cc//bbs/job/M.1294984072.A.79A.html',
#  'https://www.ptt.cc//bbs/job/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%AA%A2%E8%88%89%E5%B0%88%E5%8D%80',
#  'https://www.ptt.cc//bbs/job/search?q=author%3Acin',
#  'https://www.ptt.cc//bbs/job/M.1296534356.A.D1E.html',
#  'https://www.ptt.cc//bbs/job/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E5%8D%B3%E6%97%A5%E8%B5%B7%E5%85%BC%E8%81%B7%E6%96%87%E4%B8%8D%E5%8F%AF%E8%B2%BCJOB%E6%9D%BF',
#  'https://www.ptt.cc//bbs/job/search?q=author%3Acin',
#  'https://www.ptt.cc//bbs/job/M.1297170305.A.D86.html',
# ...

# %%
filtered_urls = [url for url in allurl if url.startswith('https://www.ptt.cc//bbs/job/M.')]
print(filtered_urls)
# Out:
# ['https://www.ptt.cc//bbs/job/M.1294984072.A.79A.html', 'https://www.ptt.cc//bbs/job/M.1296534356.A.D1E.html', 'https://www.ptt.cc//bbs/job/M.1297170305.A.D86.html', 'https://www.ptt.cc//bbs/job/M.1299166021.A.CF9.html', 'https://www.ptt.cc//bbs/job/M.1358841354.A.611.html', 'https://www.ptt.cc//bbs/job/M.1358843306.A.B97.html', 'https://www.ptt.cc//bbs/job/M.1358860428.A.1FD.html', 'https://www.ptt.cc//bbs/job/M.1359554986.A.336.html', 'https://www.ptt.cc//bbs/job/M.1360168331.A.98A.html', 'https://www.ptt.cc//bbs/job/M.1361460578.A.8B4.html', 'https://www.ptt.cc//bbs/job/M.1362375161.A.852.html', 'https://www.ptt.cc//bbs/job/M.1364451392.A.2F8.html', 'https://www.ptt.cc//bbs/job/M.1364535488.A.107.html', 'https://www.ptt.cc//bbs/job/M.1364882642.A.BD8.html', 'https://www.ptt.cc//bbs/job/M.1364991091.A.254.html', 'https://www.ptt.cc//bbs/job/M.1365506216.A.196.html', 'https://www.ptt.cc//bbs/job/M.1367059295.A.F9C.html', 'https://www.ptt.cc//bbs/job/M.1367072028.A.69D.html', 'https:
# ...

# %%
titles = list()
contents = list()
for i in filtered_urls:
    res = requests.get(i)
    res.encoding = 'utf-8'
    soup = BeautifulSoup(res.text, "html.parser")
    title_tags = soup.find_all(class_='article-meta-value')
    titles.append(title_tags)
    main_content = soup.find_all('div', {'id': 'main-content'})
    content = main_content[0].get_text()
    print(content)
# Out:
# 作者cin (Stress stress stress)看板job標題[公告] 檢舉專區時間Fri Jan 14 13:47:48 2011
# 由於板上文章相當多
# 麻煩板友們幫幫忙
# 若發現有不合板規的文章 或是 不合板規的推(噓)文
# 請在本篇檢舉
#
# 謝謝大家
#
# → cin         : ------------------------Thanks------------------ 02/21 11:46
# 推 q2520q      : #1Z_p9HmB 月休6日未有加班費算法 03/02 15:00
# → cin         : ---------------------------Thanks--------------- 03/02 20:15
# ※ 編輯: cin (111.249.65.124 臺灣), 03/02/2023 20:15:34
# → nht         : #1a0ETq94 不知所云 03/06 00:50
# → ipipwrong   : #1a1Nc_go 薪資面議 03/06 13:48
# 推 q2520q      : #1ZnaMhLl 要求照片 03/06 21:24
# → cin         : #1a1Nc_go 已經寫上薪資 03/06 21:27
# → cin         : --------------------Thanks-------------------- 03/06 21:28
# 推 ipipwrong   : #1a2oeUi0月休四天 03/10 22:14
# 推 Elvis1991   : #1a3V2s0f 缺標語 03/13 07:26
# → cin         : #1a2oeUi0 月休天數已經更改 03/13 20:15
# → nht         : #1a3-R4Jt 月休不明 03/14 13:19
# → cin         : ------------------------Thanks------------------ 03/15 19:44
# → nht         : #1a4m6fJs 缺標語 03/17 01:15
# ...

# %%
from bs4 import BeautifulSoup

# %%
response = requests.get(htmlRUL)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, "html.parser")
soup.encoding = 'utf-8'
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 job 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/job/index.html"><span class="board-label">看板 </span>job</a>
# <a class="right small" href="/about.html">關於我們</a>
# ...

# %%
paragraphs = soup.find_all(class_="title")

for p in paragraphs:
    print(p.text)
# Out:
#
# 				modechao27: 缺標語
#
#
#
#
# 				elongation: 缺標語
#
#
#
# [台北] 國北教大自然系誠徵國科會計畫專任助理
#
#
# [台北] 勞資管理顧問公司 誠徵【業務助理】
#
#
# [徵]夏威夷花式鐵板燒內外場鐵板師傅學徒
#
#
# [北部] 中和徵內勤業務
#
#
# [北部] 國立清華大學中國文學系誠徵計畫行政助理
#
#
# [台北] 永和徵國小一年級班導師
#
#
# [中部] [大雅] 短期行政人員
#
#
# [台北] 台大國際產學聯盟誠徵國科會計畫助理專任
#
#
# [台北] 調鼎法律工場/律師助理
#
#
# [中部] 乂迪生科技 誠徵   晚班線上客服專員
#
#
# [台北] 包裝人員
#
#
# [北部] 門市正職/網路行銷人員(三峽北大)
#
#
# [台北] 台灣自殺防治學會 徵專任助理
#
#
# [台南] 台南市安平區誠徵會計助理
#
#
# [台北] 台大生機系先進材料實驗室徵專任研究助理
#
#
# [台北] 臺大醫院誠徵住院整合照護管理師
#
#
# [北部] 新北市就業服務處-徵業務輔導員
#
#
# [公告] 檢舉專區 噓徵人文 請寫上理由
#
#
# [公告] 2023年1/1增修板規  罰則修訂
#
#
# [公告] 不實資方 處理方式 ([黑名]前必看)
#
#
# [公告] 關於文章內容 或推/噓文內容 為"酸"言
#
#
# [公告] 徵人文章 要求貼照片 一律水桶七天

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="zh">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>è£å¤å®¶</title>
# <meta content="åµæ°ãæºæ
# §ãå¤æ¨£çä¸­æè£å¤æª¢ç´¢æå" name="description">
# <meta content="è£å¤æ¸,å¤æ±ºæ¸,å¤æ±º,è£å®" name="keywords">
# <meta content="humans.txt" name="author"/>
# <link href="favicon.png" rel="shortcut icon" type="image/x-icon"/>
# <meta content="width=960, initial-scale=1.0" name="viewport"/>
# <meta content="è£å¤å®¶" property="og:title">
# <meta content="åµæ°ãæºæ
# §ãå¤æ¨£çä¸­æè£å¤æª¢ç´¢æå" property="og:description">
# <meta content="article" property="og:type"/>
# <meta content="//www.lawplus.com.tw" property="og:url"/>
# <meta content="//www.lawplus.com.tw/img/logo.s.png" property="og:image"/>
# <meta content="è£å¤å®¶" property="og:site_name"/>
# <link href="css/kimi/jquery-ui-1.9.2.custom.min.css" rel="stylesheet"/>
# ...

# %%
input_tag[0]['value']
