# %%
import requests
from bs4 import BeautifulSoup
response = requests.get(
    "https://www.taifex.com.tw/cht/3/dailyFXRate")
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify())  #輸出排版後的HTML內容
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# <head>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# </head>
# <html lang="zh-TW" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="/cht/resources/front/cht/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="https://www.taifex.com.tw/chinese/images/fb_logo.jpg" property="og:image">
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#     <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#     <title>
#      臺灣期貨交易所-交易資訊-每日外幣參考匯率查詢
#     </title>
#     <link href="/cht/resources/front/cht/css/global.css" rel="stylesheet" type="text/css"/>
#     <link href="/cht/resources/front/cht/css/content.css" rel="stylesheet" type="text/css"/>
#     <link href="/cht/resources/front/cht/css/index.css" rel="stylesheet" type="text/css"/>
# ...

# %%
#paragraphs = soup.find_all("tbody")
paragraphs = soup.find_all("div", align="center")
paragraphs1 = soup.find_all("td", align="center")
print(paragraphs+paragraphs1)
#print(paragraphs)
# Out:
# [<div align="center">日期</div>, <div align="center">美元／新台幣</div>, <div align="center">人民幣／新台幣</div>, <div align="center">歐元／美元</div>, <div align="center">美元／日幣</div>, <div align="center">英鎊／美元</div>, <div align="center">澳幣／美元</div>, <div align="center">美元／港幣</div>, <div align="center">美元／人民幣</div>, <div align="center">美元／南非幣</div>, <div align="center">紐幣／美元</div>, <td align="center" bgcolor="#FFFFFF" class="13bk" height="16">2023/05/02</td>, <td align="center" bgcolor="#FFFFFF">
# 								30.782</td>, <td align="center" bgcolor="#FFFFFF">
# 								4.426698</td>, <td align="center" bgcolor="#FFFFFF">
# 								1.09645</td>, <td align="center" bgcolor="#FFFFFF">
# 								137.575</td>, <td align="center" bgcolor="#FFFFFF">
# 								1.2467</td>, <td align="center" bgcolor="#FFFFFF">
# 								0.6694</td>, <td align="center" bgcolor="#FFFFFF">
# 								7.84995</td>, <td align="center" bgcolor="#FFFFFF">
# 								6.9537</td>, <td align="center" bgcolor="#FFFFFF">
# ...

# %%
for p in (paragraphs+paragraphs1):
#for p in (paragraphs):    
    print(p.text)
# Out:
# 日期
# 美元／新台幣
# 人民幣／新台幣
# 歐元／美元
# 美元／日幣
# 英鎊／美元
# 澳幣／美元
# 美元／港幣
# 美元／人民幣
# 美元／南非幣
# 紐幣／美元
# 2023/05/02
#
# 								30.782
#
# 								4.426698
#
# 								1.09645
#
# 								137.575
#
# 								1.2467
#
# 								0.6694
#
# 								7.84995
#
# 								6.9537
#
# 								18.42765
#
# 								0.6193
# 2023/05/03
#
# 								30.746
#
# 								4.443842
#
# 								1.1037
#
# 								135.595
#
# 								1.2517
#
# 								0.66585
#
# 								7.85005
#
# 								6.9188
#
# 								18.3935
#
# 								0.6233
# 2023/05/04
#
# 								30.666
#
# 								4.430746
#
# 								1.1055
#
# 								134.625
#
# 								1.2567
#
# 								0.66665
#
# 								7.84785
#
# 								6.9212
#
# 								18.2642
#
# 								0.6239
# 2023/05/05
#
# 								30.641
#
# 								4.429677
#
# 								1.1028
#
# 								134.085
#
# 								1.2603
#
# 								0.67265
#
# 								7.84785
#
# 								6.9172
#
# 								18.36095
#
# 								0.62935
# 2023/05/08
#
# 								30.673
#
# 								4.43188
#
# 								1.1047
# ...
