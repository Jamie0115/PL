# %%
import pandas as pd

data = pd.read_csv("money.csv")
data
# Out:
#           日期  美元／新台幣   人民幣／新台幣    歐元／美元    美元／日幣    英鎊／美元    澳幣／美元    美元／港幣  \
# 0   2023/1/3  30.698  4.445377  1.05875  130.335  1.19585  0.67555  7.81485
# 1   2023/1/4  30.714  4.461055  1.06280  130.055  1.20730  0.68685  7.81845
# 2   2023/1/5  30.710  4.461487  1.06120  132.855  1.20090  0.68040  7.81410
# 3   2023/1/6  30.712  4.472558  1.05240  134.285  1.19030  0.67525  7.81090
# 4   2023/1/9  30.520  4.501883  1.06910  132.115  1.21505  0.69345  7.80695
# ..       ...     ...       ...      ...      ...      ...      ...      ...
# 93  2023/6/1  30.740  4.308826  1.06700  139.855  1.24190  0.64960  7.83225
# 94  2023/6/2  30.655  4.325206  1.07640  139.015  1.25290  0.66165  7.83465
# 95  2023/6/5  30.695  4.307000  1.06950  140.275  1.24085  0.65970  7.83700
# 96  2023/6/6  30.728  4.310063  1.07040  139.195  1.24290  0.66615  7.84255
# 97  2023/6/7  30.712  4.308249  1.06860  139.295  1.24180  0.66760  7.84085
#
#      美元／人民幣    美元／南非幣    紐幣／美元
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("money.csv")

# %%
x = list(df['日期'])
print(x)
type(x)
y1 = list(df['美元／新台幣'])
print(y1)
type(y1)
y2 = list(df['人民幣／新台幣'])
print(y2)
type(y2)
y3 = list(df['歐元／美元'])
print(y3)
type(y3)
y4 = list(df['美元／日幣'])
print(y4)
type(y4)
y5 = list(df['英鎊／美元'])
print(y5)
type(y5)
y6 = list(df['澳幣／美元'])
print(y6)
type(y6)
y7 = list(df['美元／港幣'])
print(y7)
type(y7)
y8 = list(df['美元／人民幣'])
print(y8)
type(y8)
y9 = list(df['美元／南非幣'])
print(y9)
type(y9)
y10 = list(df['紐幣／美元'])
print(y10)
type(y10)
# Out:
# ['2023/1/3', '2023/1/4', '2023/1/5', '2023/1/6', '2023/1/9', '2023/1/10', '2023/1/11', '2023/1/12', '2023/1/13', '2023/1/16', '2023/1/17', '2023/1/30', '2023/1/31', '2023/2/1', '2023/2/2', '2023/2/3', '2023/2/6', '2023/2/7', '2023/2/8', '2023/2/9', '2023/2/10', '2023/2/13', '2023/2/14', '2023/2/15', '2023/2/16', '2023/2/17', '2023/2/20', '2023/2/21', '2023/2/22', '2023/2/23', '2023/2/24', '2023/3/1', '2023/3/2', '2023/3/3', '2023/3/6', '2023/3/7', '2023/3/8', '2023/3/9', '2023/3/10', '2023/3/13', '2023/3/14', '2023/3/15', '2023/3/16', '2023/3/17', '2023/3/20', '2023/3/21', '2023/3/22', '2023/3/23', '2023/3/24', '2023/3/27', '2023/3/28', '2023/3/29', '2023/3/30', '2023/3/31', '2023/4/6', '2023/4/7', '2023/4/10', '2023/4/11', '2023/4/12', '2023/4/13', '2023/4/14', '2023/4/17', '2023/4/18', '2023/4/19', '2023/4/20', '2023/4/21', '2023/4/24', '2023/4/25', '2023/4/26', '2023/4/27', '2023/4/28', '2023/5/2', '2023/5/3', '2023/5/4', '2023/5/5', '2023/5/8', '2023/5/9', '2023/5/10', '2023/5/11
# ...

# %%
plt.title("2023_US & TWD") # 圖的標題
plt.xlabel("date") # x軸的名稱
plt.plot(x,y1,linewidth = 5, color = "red")
plt.ylabel("USD") # y軸的名稱
plt.show()

#plt.plot(x,y) # 繪製x,y軸的圖
#plt.show() # 顯現圖形

# %%
#設定figure空圖
fig = plt.figure()


#新建子圖1
ax1 = fig.add_subplot(2, 2, 1)
# 圖的標題
plt.title("2023_US & TWD") 
# x軸的名稱
plt.xlabel("date")
# y軸的名稱
plt.ylabel("USD") 
ax1.plot(x, y1, color='red', linestyle='-', linewidth=3)

#新建子圖2
ax1 = fig.add_subplot(2, 2, 2)
# 圖的標題
plt.title("2023_CNY & TWD")
# x軸的名稱
plt.xlabel("date") 
# y軸的名稱
plt.ylabel("CNY") 
ax1.plot(x, y2, color='red', linestyle='-', linewidth=3)


#新建子圖3
ax1 = fig.add_subplot(2, 2, 3)
# 圖的標題
plt.title("2023_EUR & USD")
# x軸的名稱
plt.xlabel("date")
# y軸的名稱
plt.ylabel("EUR") 
ax1.plot(x, y3, color='red', linestyle='-', linewidth=3)

#新建子圖4
ax1 = fig.add_subplot(2, 2, 4)
# 圖的標題
plt.title("2023_USD & JPY")
# x軸的名稱
plt.xlabel("date") 
# y軸的名稱
plt.ylabel("USD") 
ax1.plot(x, y4, color='red', linestyle='-', linewidth=3)

plt.tight_layout()

# %%
#設定figure空圖
fig = plt.figure()


#新建子圖1
ax1 = fig.add_subplot(2, 2, 1)
# 圖的標題
plt.title("2023_GBP & USD") 
# x軸的名稱
plt.xlabel("date")
# y軸的名稱
plt.ylabel("GBP") 
ax1.plot(x, y5, color='red', linestyle='-', linewidth=3)

#新建子圖2
ax1 = fig.add_subplot(2, 2, 2)
# 圖的標題
plt.title("2023_AUD & USD")
# x軸的名稱
plt.xlabel("date") 
# y軸的名稱
plt.ylabel("AUD") 
ax1.plot(x, y6, color='red', linestyle='-', linewidth=3)


#新建子圖3
ax1 = fig.add_subplot(2, 2, 3)
# 圖的標題
plt.title("2023_USD & HKD")
# x軸的名稱
plt.xlabel("date")
# y軸的名稱
plt.ylabel("USD") 
ax1.plot(x, y7, color='red', linestyle='-', linewidth=3)

#新建子圖4
ax1 = fig.add_subplot(2, 2, 4)
# 圖的標題
plt.title("2023_USD & CNY")
# x軸的名稱
plt.xlabel("date") 
# y軸的名稱
plt.ylabel("USD") 
ax1.plot(x, y8, color='red', linestyle='-', linewidth=3)

plt.tight_layout()

# %%
#設定figure空圖
fig = plt.figure()


#新建子圖1
ax1 = fig.add_subplot(2, 2, 1)
# 圖的標題
plt.title("2023_USD & ZAR") 
# x軸的名稱
plt.xlabel("date")
# y軸的名稱
plt.ylabel("USD") 
ax1.plot(x, y9, color='red', linestyle='-', linewidth=3)

#新建子圖2
ax1 = fig.add_subplot(2, 2, 2)
# 圖的標題
plt.title("2023_NZD & USD")
# x軸的名稱
plt.xlabel("date") 
# y軸的名稱
plt.ylabel("NZD") 
ax1.plot(x, y10, color='red', linestyle='-', linewidth=3)
